# %%
import pymongo
client = pymongo.MongoClient(
    "mongodb+srv://root:root@cluster-aqz47.mongodb.net/test?retryWrites=true&w=majority"
)

myDatabase = client['personal_project']
myCollection = myDatabase['students']
myCollection.insert_one({
   "registration_id": 15463,
    "student_name": "Sushma Kumari",
    "date_of_birth": "08/01/2002",
    "email": "sushma@gmail.com",
    "address": "Mathura",
    "department": "Computer Science",
    "sub1": 58,
    "sub2": 38,
    "sub3": 78,
    "sub4": 89,
    "sub5": 78
})
# # print(myCollection)
# data = myCollection.find({"registration_id": 15265}).count_documents()
# data = myDatabase.myCollection.find({"registration_id": 15465})
# print(data)

# %%
from faker import Faker
fake = Faker()
Faker.seed(0)

data=fake.date_between(start_date='-26y', end_date='-22y')
print(data)
# Out:
# 1997-01-13

# %%
import random

from faker import Faker
from faker.providers import BaseProvider

fake = Faker()

# Our custom provider inherits from the BaseProvider
class TravelProvider(BaseProvider):
    def destination(self):
        destinations = ['NY', 'CO', 'CA', 'TX', 'RI']

        # We select a random destination from the list and return it
        return random.choice(destinations)

# Add the TravelProvider to our faker object
fake.add_provider(TravelProvider)

# We can now use the destination method:
print(fake.destination())
# Out:
# NY

# %%
import os
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir() if isfile(join('', f))]
onlyfiles
# Out:
# ['index.py',
#  'test.log.4',
#  'test.log.1',
#  'Untitled.ipynb',
#  'test.log.3',
#  'myLogger.py',
#  'test.log.5',
#  'test.log',
#  'dbConnection.py',
#  'test.log.2']

# %%
st = 'index.csv'
sc = st.split('.')
sc[0]
filesAdded = dict()
filesAdded[sc[0]]=1
filesAdded
# Out:
# {'index': 1}

# %%
#  src/DataGeneration
myPath ='/home/user/nitish/personal_projects/python-csv-to-mongodb-multithreading/src/DataGeneration'

filesFetched = [f for f in listdir(myPath) if isfile(join(myPath, f))]
filesFetched
# Out:
# ['student.csv', 'fakedata.py']

# %%
st = 'student_'
st = st+'1'
st = st+'.csv'
st
sc = st.split('.')
sc[0]
filesAdded[sc[0]] =1 
print(sc[0] in filesAdded)
# Out:
# True

# %%
import logging
import threading
import time


def thread_function(name):
    logging.info("Thread %s: starting", name)
    time.sleep(2)
    logging.info("Thread %s: finishing", name)


if __name__ == "__main__":
    format = "%(asctime)s: %(message)s"
    logging.basicConfig(format=format, level=logging.INFO, datefmt="%H:%M:%S")

    logging.info("Main    : before creating thread")
    x = threading.Thread(target=thread_function, args=(1, ))
    logging.info("Main    : before running thread")
    x.start()
    logging.info("Main    : wait for the thread to finish")
    # x.join()
    logging.info("Main    : all done")
# Out:
# 02:21:41: Main    : before creating thread
# 02:21:41: Main    : before running thread
# 02:21:41: Thread 1: starting
# 02:21:41: Main    : wait for the thread to finish
# 02:21:41: Main    : all done
# 02:21:43: Thread 1: finishing

# %%
import pymongo
import pandas as pd
client = pymongo.MongoClient(
    "mongodb+srv://root:root@cluster-aqz47.mongodb.net/test?retryWrites=true&w=majority"
)
myDatabase = client['personal_project']
myCollection = myDatabase['students']
cursor=myCollection.find({})
df =  pd.DataFrame(list(cursor))
df.head()
# Out:
#                         _id  registration_id    student_name date_of_birth  \
# 0  5ece5059e3694edbbf2cfac9          4494612     Tonya Brown    1996-02-03
# 1  5ece5059e3694edbbf2cfaca          3415111     Kevin Roman    1995-12-30
# 2  5ece5059e3694edbbf2cfacb          3070579     Ethan Evans    1995-05-24
# 3  5ece5059e3694edbbf2cfacc          8059923    Peter Miller    1995-02-01
# 4  5ece5059e3694edbbf2cfacd          7660718  Cheryl Jackson    1996-09-09
#
#                              email                      address  department  \
# 0              jason30@gilbert.com  775 Kathleen Trail Apt. 552   Metallury
# 1  kimjennifer@matthews-graves.com         6530 Daniel Parkways   Metallury
# 2      samuelrodriguez@harris.info  40821 Samuel Coves Apt. 102   Petroleum
# 3        ffranklin@lopez-patel.com            683 Allison Mount  Electrical
# 4            hortoneric@torres.com  0150 Aaron Viaduct Apt. 695  Electrical
#
#    sub1  sub2  sub3  sub4  sub5
# 0    87    12    33    54    78
# 1    86    49    66    25    87
# 2    80    50    36    67    37
# 3    20    88    22    92    58
# 4    31    88    90    48    66

# %%
df['total_marks'] = df['sub1']+df['sub2']+df['sub3']+df['sub4']+df['sub5']
df
# Out:
#                             _id  registration_id      student_name  \
# 0      5ece5059e3694edbbf2cfac9          4494612       Tonya Brown
# 1      5ece5059e3694edbbf2cfaca          3415111       Kevin Roman
# 2      5ece5059e3694edbbf2cfacb          3070579       Ethan Evans
# 3      5ece5059e3694edbbf2cfacc          8059923      Peter Miller
# 4      5ece5059e3694edbbf2cfacd          7660718    Cheryl Jackson
# ...                         ...              ...               ...
# 39995  5ece5063e3694edbbf2d9704          5933516      Gregory Webb
# 39996  5ece5063e3694edbbf2d9705          6595218     Julie Salazar
# 39997  5ece5063e3694edbbf2d9706          3551216     Melinda Jones
# 39998  5ece5063e3694edbbf2d9707          1031937  Erica Harrington
# 39999  5ece5063e3694edbbf2d9708          3396633      Dustin Lyons
#
#       date_of_birth                            email  \
# 0        1996-02-03              jason30@gilbert.com
# 1        1995-12-30  kimjennifer@matthews-graves.com
# 2        1995-05-24      samuelrodriguez@harris.info
# 3        1995-02-01        ffranklin@lopez-patel.com
# 4        1996-09-09            hortoneric@torres.com
# ...             ...                              ...
# 39995    1998-03-03              fatkinson@gmail.com
# 39996    1994-06-24           keithwilliams@bass.net
# 39997    1995-03-09             oalexander@yahoo.com
# 39998    1996-10-21           jennifer84@hotmail.com
# 39999    1995-09-22              fklein@thornton.com
#
#                                address  department  sub1  sub2  sub3  sub4  \
# 0          775 Kathleen Trail Apt. 552   Metallury    87    12    33    54
# 1                 6530 Daniel Parkways   Metallury    86    49    66    25
# 2          40821 Samuel Coves Apt. 102   Petroleum    80    50    36    67
# 3                    683 Allison Mount  Electrical    20    88    22    92
# 4          0150 Aaron Viaduct Apt. 695  Electrical    31    88    90    48
# ...                                ...         ...   ...   ...   ...   ...
# 39995       446 Juan Parkway Suite 503       Civil    12    12    13    63
# 39996  064 Hernandez Village Suite 442   Metallury    24    90    69    11
# 39997          97384 Ali Pine Apt. 541  Electrical    83    51    99    73
# 39998                22260 Nunez Route        E&TC    69    34    13   100
# 39999              79792 Miller Branch   Petroleum    23    93    73    50
#
#        sub5  total_marks
# 0        78          264
# 1        87          313
# 2        37          270
# 3        58          280
# 4        66          323
# ...     ...          ...
# 39995    37          137
# 39996    42          236
# 39997    58          364
# 39998    84          300
# 39999    74          313
#
# [40000 rows x 13 columns]

# %%
groupByDepartment=df.groupby('department')

# %%
df[df["registration_id"]==8977143]
# Out:
#                            _id  registration_id     student_name  \
# 8236  5ece5059e3694edbbf2d4621          8977143  Michael Johnson
#
#      date_of_birth                     email           address department  \
# 8236    1998-05-11  jeremymeyers@hotmail.com  2465 Shawn Drive   Aviation
#
#       sub1  sub2  sub3  sub4  sub5  total_marks
# 8236    99    65    95    74    16          349

# %%
groupByDepartment.max()
# Out:
#                                  _id  registration_id        student_name  \
# department
# Aviation    5ece5063e3694edbbf2d9701          8977143        Zachary York
# Chemical    5ece5063e3694edbbf2d9702          8978114           Zoe Keith
# Civil       5ece5063e3694edbbf2d9704          8972772         Zoe Pearson
# Computers   5ece5063e3694edbbf2d9700          8977972           Zoe Jones
# E&TC        5ece5063e3694edbbf2d9707          8978537         Zoe Simmons
# Electrical  5ece5063e3694edbbf2d9706          8977006   Zachary Wilkerson
# IT          5ece5063e3694edbbf2d96f1          8977904        Zachary Wade
# Mechanical  5ece5063e3694edbbf2d96ed          8975053         Zoe Ramirez
# Metallury   5ece5063e3694edbbf2d9705          8978377  Zachary Strickland
# Petroleum   5ece5063e3694edbbf2d9708          8974297       Zachary Young
#
#            date_of_birth                         email  \
# department
# Aviation      1998-05-26             zwilson@gmail.com
# Chemical      1998-05-26    zyoung@anderson-thomas.com
# Civil         1998-05-26  zwilliams@patrick-stokes.com
# Computers     1998-05-26            zzamora@thomas.net
# E&TC          1998-05-25             zwright@yahoo.com
# Electrical    1998-05-26            zwilliams@cain.net
# IT            1998-05-26    zwilliams@payne-potter.org
# Mechanical    1998-05-26               zwolfe@reid.net
# Metallury     1998-05-26           zwilson@hotmail.com
# Petroleum     1998-05-26           zwilliams@yahoo.com
#
#                                   address  sub1  sub2  sub3  sub4  sub5  \
# department
# Aviation             99984 Powell Islands   100   100   100   100   100
# Chemical              9999 Carter Valleys   100   100   100   100   100
# Civil        9999 Timothy Grove Suite 087   100   100   100   100   100
# Computers   9994 Spencer Squares Apt. 144   100   100   100   100   100
# E&TC                9997 Anderson Centers   100   100   100   100   100
# Electrical      99960 Green Fort Apt. 192   100   100   100   100   100
# IT                     9999 Shirley Crest   100   100   100   100   100
# Mechanical       99996 Lisa Oval Apt. 230   100   100   100   100   100
# Metallury       99986 Diana Isle Apt. 921   100   100   100   100   100
# Petroleum               99972 Diane Trace   100   100   100   100   100
#
#             total_marks
# department
# Aviation            448
# Chemical            456
# Civil               474
# Computers           471
# E&TC                446
# Electrical          457
# IT                  472
# Mechanical          465
# Metallury           449
# Petroleum           458

# %%
df.dtypes
# Out:
# _id                object
# registration_id     int64
# student_name       object
# date_of_birth      object
# email              object
# address            object
# department         object
# sub1                int64
# sub2                int64
# sub3                int64
# sub4                int64
# sub5                int64
# dtype: object

# %%
df=df.groupby(['department']).apply(lambda x : x.sort_values(['total_marks'],ascending = False)).reset_index(drop = True)
reportOfTopStudents=df.groupby('department').head(5)
reportOfTopStudents
# Out:
#                             _id  registration_id         student_name  \
# 0      5ece5063e3694edbbf2d70b7          5918164   Patricia Armstrong
# 1      5ece5059e3694edbbf2d5c8e          1186533          Troy Rogers
# 2      5ece5059e3694edbbf2d274c          6725465        Michele Ayala
# 3      5ece5059e3694edbbf2d6617          6951079      Jenny Castaneda
# 4      5ece5059e3694edbbf2d11d8          3266131      Matthew Jackson
# 7994    0848 Elizabeth Canyon Suite 790       Civil    72    90    90    94
# 7995                1892 Flores Mission       Civil    90    98    72    94
# 11998              5382 Bradford Groves   Computers    91    94    96    99
# 11999                    156 Bush Views   Computers    96    92    99    80
# 12000        10259 Dixon Cliff Apt. 908   Computers    98    82   100    98
# 12001                45065 Jackson Lock   Computers    86    95    82    92
# 12002                79573 Sanders Walk   Computers    99    85    63    91
# 15981      1888 Stanley Plaza Suite 669        E&TC    94    89    92    90
# 15982                   727 Mcgee Ranch        E&TC    91    81   100    79
# 15983   67177 Martinez Village Apt. 979        E&TC    75    79    99    93
# 15984                 213 Padilla Creek        E&TC    95    80    92    75
# 15985                5560 Martinez Loop        E&TC    86    92    80    90
# 20073        36543 Leach Track Apt. 844  Electrical    92   100    85    98
# 20074      772 Middleton Cliff Apt. 208  Electrical    99    90    90    79
# 20075                3707 Mueller Locks  Electrical    87    82    97    93
# 20076     8038 Nelson Turnpike Apt. 144  Electrical    82    97    90    99
# 20077         3261 Grant Haven Apt. 821  Electrical    84    89    98    96
# 24005     6690 Schwartz Plaza Suite 302          IT    94    95    95    92
# 24006                   0941 Tina Drive          IT    95    89    71   100
# 24007          733 Kayla Club Suite 293          IT    76    97    90    89
# 24008       56830 Pamela Lane Suite 512          IT    97    82    75    91
# 24009                    744 Jason Fall          IT    92    86    98    91
# 27859      46519 Jacob Cliffs Suite 310  Mechanical    89    96    99    81
# 27860        418 Woods Freeway Apt. 649  Mechanical    95    99    85    98
# 27861      0256 Ramsey Summit Suite 620  Mechanical    95    94    96    77
# 27862              5336 Bonilla Freeway  Mechanical    80    95   100    98
# 27863               250 Tyler Mountains  Mechanical    89    86    98    84
# 31897                  18275 Parks Oval   Metallury    79    83    96    98
# 31898      93316 Eric Valleys Suite 091   Metallury    63   100    93    93
# 31899                32842 Lauren Lakes   Metallury    82    90    87    89
# 31900       357 Delgado Garden Apt. 221   Metallury    96    99    96    57
# 31901    8775 William Islands Suite 059   Metallury    94    66    93    93
# 36039          147 Nguyen Walk Apt. 500   Petroleum    84    99    90    91
# 36040                57516 Sarah Branch   Petroleum    96    91    85    91
# 36041               42549 Jarvis Bypass   Petroleum    96    99   100    67
# 36042          372 Megan Isle Suite 857   Petroleum    99    95    73    92
# 36043  0111 Christopher Roads Suite 545   Petroleum    91    82    79    95
#
#        sub5  total_marks
# 0        94          448
# 1        96          445
# 2        80          439
# 3        85          437
# 4        91          434
# 3940     79          456
# 3941     85          452
# 3942     98          443
# 3943     87          442
# 3944     78          440
# 7991     83          474
# 7992     98          456
# 7993     89          450
# 7994     99          445
# 7995     87          441
# 11998    91          471
# 11999    94          461
# 12000    64          442
# 12001    86          441
# 12002   100          438
# 15981    81          446
# 15982    95          446
# 15983    98          444
# 15984    99          441
# 15985    90          438
# 20073    82          457
# 20074    97          455
# 20075    92          451
# 20076    83          451
# 20077    81          448
# 24005    96          472
# 24006    98          453
# 24007    97          449
# 24008    96          441
# 24009    70          437
# 27859   100          465
# 27860    86          463
# 27861    97          459
# 27862    77          450
# 27863    87          444
# 31897    93          449
# 31898   100          449
# 31899    97          445
# 31900    96          444
# 31901    98          444
# 36039    94          458
# 36040    87          450
# 36041    85          447
# 36042    83          442
# 36043    94          441
